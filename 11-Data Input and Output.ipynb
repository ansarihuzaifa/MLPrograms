# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Arbaz'

# %%
df=pd.read_csv('example')            #Reading input from a CSV(comma separeted value)

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('example1',index=False)          #creates or saves file as a CSV file #if we do not give index as false then it will
                                           #  automatically reads the index as data

# %%
df=pd.read_csv('example1')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('example2',index=True)

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df=pd.read_csv('example2')

# %%
df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
    # Excel Input

# %%
df1=pd.read_excel('Excel_sample.xlsx',sheet_name='Sheet1')      #Reading the excel file as input

# %%
df1
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df1=pd.read_excel('Conditional_Formating.xlsx')

# %%
df1
# Out:
#                                     Conditional Formatting  Unnamed: 1  \
# NaN NaN                                                NaN         NaN
#     NaN  1) Conditional Formatting for cells in a highl...         NaN
#     NaN                       TRUE = Cell gets Formatting.         NaN
#     NaN                   FALSE = Cell NOT get Formatting.         NaN
#     NaN  2) Conditional Formatting can be applied to ce...         NaN
#     NaN                                                NaN         NaN
#     NaN                            Built-in features like:         NaN
#     NaN                                1. Contains a value         NaN
#     NaN                                    2. Top 3 values         NaN
#     NaN                                   3. Above Average         NaN
#     NaN                                       4. Data Bars         NaN
#     NaN                         5. Color Scales (Heat Map)         NaN
# ...
